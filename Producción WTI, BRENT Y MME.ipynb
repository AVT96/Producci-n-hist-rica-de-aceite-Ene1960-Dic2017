# %%
% matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

prod = pd.read_csv('2005-2017.csv')
prod.columns
print ('tipo', type(prod))
WTI = prod ['WTI']
BRENT = prod['BRENT']
MME = prod['MME']
print ('WTI', type(WTI), 'BRENT', type(BRENT), 'MME', type('MME'))
# Out:
# tipo <class 'pandas.core.frame.DataFrame'>
# WTI <class 'pandas.core.series.Series'> BRENT <class 'pandas.core.series.Series'> MME <class 'str'>

# %%
plt.figure(figsize=[18,7])
plt.style.use('bmh')

plt.plot(WTI, '-' , color = 'red' )
plt.plot(BRENT, '-' , color = 'blue' )
plt.plot(MME, '-' , color = 'green' )
plt.grid(color='blue', alpha=0.4)

plt.xlabel('Años', color='k', fontsize='x-large')

plt.ylabel('USD/Bbl', fontsize='x-large', color='k')

plt.title('Promedio Mensual Precio del Petróleo WTI,BRENT y Mezcla Mexicana', fontsize='x-large', color='black')
plt.xticks( [0,],
           ['2005'], 
               rotation=60, color='k')
plt.ylim(0,140)
plt.legend()
